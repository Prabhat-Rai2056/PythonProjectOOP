# %%
Age=dict()


def switch(i):
    switcher={
                    1: InsertData,
                    2: UpdateData,
                    3: DeleteData,
                    4: ShowData
             }
    return switcher.get(i,'no option found')

    
def App(): 
    while True:
        print("1.Enter the data:")
        print("2.Update the data")
        print("3.Delete the data")
        print("4.Show the data")
        print("Enter 0 to quit")
        opt=int(input("Please choose option from above:"))
        if (opt > 0 and opt <5):
            ans=switch(opt)
            ans()
            
        elif (opt==0):
            break


def InsertData():
    name=input("Enter Name:")
    age=int(input("Enter age:"))
    Age.update({name:age})
    print("new data added\n")
    
def UpdateData():
    name=input("Enter Name:")
    age=int(input("Enter age:"))
    if name in Age.keys():
        Age.update({name:age})
        print("new data updated\n")
    else:
        print("no item in the dictionary\n")
    
def DeleteData():
    print("Enter the key you want to delete:")
    delete=input()
    if delete in Age.keys():
        del Age[delete]
    else:
        print("no item found")
        
def ShowData():
    for i,j in Age.items():
        print(i,'=',j)
        
App()
# Out:
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:1
# Enter Name:Prabhat Rai
# Enter age:21
# new data added
#
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:4
# Prabhat Rai = 21
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:2
# Enter Name:Prabhat Rai
# Enter age:22
# new data updated
#
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:4
# Prabhat Rai = 22
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:2
# Enter Name:Ram
# Enter age:56
# no item in the dictionary
#
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:4
# Prabhat Rai = 22
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:1
# Enter Name:shyam
# Enter age:12
# new data added
#
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:4
# Prabhat Rai = 22
# shyam = 12
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:3
# Enter the key you want to delete:
# shyam
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:4
# Prabhat Rai = 22
# 1.Enter the data:
# 2.Update the data
# 3.Delete the data
# 4.Show the data
# Enter 0 to quit
# Please choose option from above:0
